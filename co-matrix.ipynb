# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
from sklearn import datasets
from tqdm import tqdm_notebook
# Out:
# C:\Users\wei\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):

# %%
data = pd.read_csv("C:/Users/wei/Documents/碩士/碩一/機器學習/mldata_CLEAN.csv")

# %%
data
# Out:
#       ID       ROA       ROE  Operating gross profit margin  cash flow  \
# 0      0  0.236765  0.169616                       0.328708   3.901708
# 1      1  0.146009  0.118674                       0.219573   1.331257
# 2      2  0.087351  0.067408                      -0.849893  -0.203389
# 3      3  0.115020  0.018088                      -0.148943  -0.018207
# 4      4  0.063002  0.069355                      -0.175562  -0.142282
# ..   ...       ...       ...                            ...        ...
# 927  927 -0.383027 -0.152583                       0.151548  -0.241523
# 928  928  1.793991  0.894483                      -0.033006   1.874715
# 929  929 -0.321048 -0.124030                       0.221052  -0.123579
# 930  930 -0.976256 -0.458234                      -0.676874  -0.179552
# 931  931  0.434877  0.308489                       0.223418  -0.523011
#
#      Debt ratio  Total asset turnover
# 0     -0.073593             -0.791617
# 1     -0.126603             -0.847592
# 2     -0.358257             -1.258075
# 3     -1.227095             -0.922225
# 4     -0.170601             -0.250526
# ..          ...                   ...
# 927   -0.169541             -0.493084
# 928   -0.479121             -1.146125
# 929   -0.282453             -1.108808
# 930   -0.018992              0.570440
# 931    0.028187             -0.511742
#
# [932 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932 entries, 0 to 931
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             932 non-null    int64
#  1   ROA                            932 non-null    float64
#  2   ROE                            932 non-null    float64
#  3   Operating gross profit margin  932 non-null    float64
#  4   cash flow                      932 non-null    float64
#  5   Debt ratio                     932 non-null    float64
#  6   Total asset turnover           932 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 51.1 KB

# %%
data.describe()
# Out:
#                ID           ROA           ROE  Operating gross profit margin  \
# count  932.000000  9.320000e+02  9.320000e+02                   9.320000e+02
# mean   465.500000  3.218894e-12 -3.218875e-12                   1.180247e-11
# std    269.189524  1.000537e+00  1.000537e+00                   1.000537e+00
# min      0.000000 -6.607505e+00 -2.562384e+01                  -1.915030e+01
# 25%    232.750000 -4.134632e-01 -1.619929e-01                  -2.730145e-01
# 50%    465.500000 -4.546191e-02  4.015217e-02                  -1.392925e-02
# 75%    698.250000  3.695771e-01  2.602243e-01                   2.958787e-01
# max    931.000000  7.980839e+00  3.106722e+00                   2.308226e+00
#
#           cash flow    Debt ratio  Total asset turnover
# count  9.320000e+02  9.320000e+02          9.320000e+02
# mean   3.111586e-11  3.218894e-12          2.360510e-11
# std    1.000537e+00  1.000537e+00          1.000537e+00
# min   -7.592940e+00 -2.370525e+00         -1.351366e+00
# 25%   -2.035524e-01 -6.832099e-01         -6.236922e-01
# 50%   -1.638324e-01 -2.558937e-03         -1.572343e-01
# 75%   -6.531759e-02  7.004888e-01          3.838568e-01
# max    1.604038e+01  2.829246e+00          8.220349e+00

# %%
data['ROA'] = data['ROA'].astype('int')
data['ROE'] = data['ROE'].astype('int')
data['Operating gross profit margin'] = data['Operating gross profit margin'].astype('int')
data['Debt ratio'] = data['Debt ratio'].astype('int')
data['Total asset turnover'] = data['Total asset turnover'].astype('int')

# %%
data.fillna(0, inplace=True)


data1 = data.drop(['ID'], axis=1)
co_matrix = []
for num in tqdm_notebook(range(len(data))):
    each_list = list(data.loc[num])
    each_co_matrix = []
    for n in range(len(each_list)):
        if n == 0:
            if each_list[n] <= -0.4:
                each_co_matrix.append('ROA <= -0.4')
            elif -0.4 < each_list[n] and each_list[n] <= -0.04:
                each_co_matrix.append('-0.4 < ROA <= -0.04')
            elif -0.04 < each_list[n] and each_list[n] <= 0.26:
                each_co_matrix.append('-0.04< ROA <= 0.36')
            else:
                each_co_matrix.append('0.36 < ROA')
        elif n == 1:
            if each_list[n] <= -0.16:
                each_co_matrix.append('ROE <= -0.16')
            elif -0.16 < each_list[n] and each_list[n] <= 0.04:
                each_co_matrix.append('-0.16 < ROE <= 0.04')
            elif 0.04 < each_list[n] and each_list[n] <= 0.26:
                each_co_matrix.append('0.04 < ROE <= 0.26')
            else:
                each_co_matrix.append('0.26 < ROE')
        elif n == 2:
            if each_list[n] <= -0.27:
                each_co_matrix.append('Operating gross profit margin <= -0.27')
            elif -0.27 < each_list[n] and each_list[n] <= -0.01:
                each_co_matrix.append('-0.27 < Operating gross profit margin <= -0.01')
            elif -0.01 < each_list[n] and each_list[n] <= 0.29:
                each_co_matrix.append('-0.01 < Operating gross profit margin <= 0.29')
            else:
                each_co_matrix.append('0.29 <Operating gross profit margin')
        elif n == 3:
            if each_list[n] <= -0.2:
                each_co_matrix.append('cash flow <= -0.2')
            elif -0.2 < each_list[n] and each_list[n] <= -0.16:
                each_co_matrix.append('-0.2 < cash flow <= -0.16')
            elif -0.16 < each_list[n] and each_list[n] <= -0.06:
                each_co_matrix.append('-0.16 < cash flow <= -0.06')
            else:
                each_co_matrix.append('-0.06 < cash flow')

        elif n == 4:
            if each_list[n] <= -0.68:
                each_co_matrix.append('Debt ratio <= -0.68')
            elif -0.68 < each_list[n] and each_list[n] <= -0.002:
                each_co_matrix.append('-0.68 < Debt ratio <= -0.002')
            elif -0.002 < each_list[n] and each_list[n] <= 0.7:
                each_co_matrix.append('-0.002 < Debt ratio <= 0.7')
            elif 0.7 < each_list[n]:
                each_co_matrix.append('0.7 < Debt ratio')
        elif n == 5:
            if each_list[n] <= -0.62:
                each_co_matrix.append('Total asset turnover <= -0.62')
            elif -0.62 < each_list[n] and each_list[n] <= -0.15:
                each_co_matrix.append('-0.62 < Total asset turnover <= -0.15')
            elif -0.15 < each_list[n] and each_list[n] <= 0.38:
                each_co_matrix.append('-0.15 < Total asset turnover <= 0.38')
            else:
                each_co_matrix.append('0.38 <Total asset turnover')
    co_matrix.append(each_co_matrix)
# Out:
#   0%|          | 0/932 [00:00<?, ?it/s]

# %%
co_matrix
# Out:
# [['-0.04< ROA <= 0.36',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   'Debt ratio <= -0.68',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   'Debt ratio <= -0.68',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   'Debt ratio <= -0.68',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   'Debt ratio <= -0.68',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   'Debt ratio <= -0.68',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
# ...
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   'cash flow <= -0.2',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   'Debt ratio <= -0.68',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   'ROE <= -0.16',
#   'Operating gross profit margin <= -0.27',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   'Total asset turnover <= -0.62'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '0.29 <Operating gross profit margin',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.002 < Debt ratio <= 0.7',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '0.38 <Total asset turnover'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '0.26 < ROE',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '0.7 < Debt ratio',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38'],
#  ['0.36 < ROA',
#   '-0.16 < ROE <= 0.04',
#   '-0.01 < Operating gross profit margin <= 0.29',
#   '-0.06 < cash flow',
#   '-0.68 < Debt ratio <= -0.002',
#   '-0.15 < Total asset turnover <= 0.38']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(co_matrix).transform(co_matrix)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
col = list(df.columns)
co_matrix_df = pd.DataFrame(columns=col)
co_matrix_weight = []
for index in tqdm_notebook(col):
    line_list = []
    for df_label in col:
        if index == df_label:
            line_list.append(0)
           #  co_matrix_weight.append([index, df_label, 0])
        else:
            df1 = df[df[index] == True]
            df1 = df1[df1[df_label] == True]
            line_list.append(len(df1))
            # co_matrix_weight.append([index, df_label, len(df1)])
            if len(df1) >= 0:
                co_matrix_weight.append([index, df_label, len(df1)])
        
    co_matrix_df.loc[index] = line_list
# Out:
#   0%|          | 0/17 [00:00<?, ?it/s]

# %%
co_matrix_df = co_matrix_df.fillna(0)

# %%
import seaborn as sns

# %%
co_matrix_df
# Out:
#                                                -0.002 < Debt ratio <= 0.7  \
# -0.002 < Debt ratio <= 0.7                                              0
# -0.01 < Operating gross profit margin <= 0.29                         109
# -0.04< ROA <= 0.36                                                      0
# -0.06 < cash flow                                                     114
# -0.15 < Total asset turnover <= 0.38                                   80
# -0.16 < ROE <= 0.04                                                    97
# -0.68 < Debt ratio <= -0.002                                            0
# 0.26 < ROE                                                             15
# 0.29 <Operating gross profit margin                                     5
# 0.36 < ROA                                                            114
# 0.38 <Total asset turnover                                             18
# 0.7 < Debt ratio                                                        0
# Debt ratio <= -0.68                                                     0
# Operating gross profit margin <= -0.27                                  0
# ROE <= -0.16                                                            2
# Total asset turnover <= -0.62                                          16
# cash flow <= -0.2                                                       0
#
#                                                -0.01 < Operating gross profit margin <= 0.29  \
# -0.002 < Debt ratio <= 0.7                                                               109
# -0.01 < Operating gross profit margin <= 0.29                                              0
# -0.04< ROA <= 0.36                                                                         1
# -0.06 < cash flow                                                                        877
# -0.15 < Total asset turnover <= 0.38                                                     602
# -0.16 < ROE <= 0.04                                                                      768
# -0.68 < Debt ratio <= -0.002                                                             710
# 0.26 < ROE                                                                                65
# 0.29 <Operating gross profit margin                                                        0
# 0.36 < ROA                                                                               881
# 0.38 <Total asset turnover                                                               123
# 0.7 < Debt ratio                                                                          46
# Debt ratio <= -0.68                                                                       17
# Operating gross profit margin <= -0.27                                                     0
# ROE <= -0.16                                                                              49
# Total asset turnover <= -0.62                                                            157
# cash flow <= -0.2                                                                          5
#
#                                                -0.04< ROA <= 0.36  \
# -0.002 < Debt ratio <= 0.7                                      0
# -0.01 < Operating gross profit margin <= 0.29                   1
# -0.04< ROA <= 0.36                                              0
# -0.06 < cash flow                                               1
# -0.15 < Total asset turnover <= 0.38                            1
# -0.16 < ROE <= 0.04                                             1
# -0.68 < Debt ratio <= -0.002                                    0
# 0.26 < ROE                                                      0
# 0.29 <Operating gross profit margin                             0
# 0.36 < ROA                                                      0
# 0.38 <Total asset turnover                                      0
# 0.7 < Debt ratio                                                1
# Debt ratio <= -0.68                                             0
# Operating gross profit margin <= -0.27                          0
# ROE <= -0.16                                                    0
# Total asset turnover <= -0.62                                   0
# cash flow <= -0.2                                               0
#
#                                                -0.06 < cash flow  \
# -0.002 < Debt ratio <= 0.7                                   114
# -0.01 < Operating gross profit margin <= 0.29                877
# -0.04< ROA <= 0.36                                             1
# -0.06 < cash flow                                              0
# -0.15 < Total asset turnover <= 0.38                         619
# -0.16 < ROE <= 0.04                                          771
# -0.68 < Debt ratio <= -0.002                                 738
# 0.26 < ROE                                                    83
# 0.29 <Operating gross profit margin                           20
# 0.36 < ROA                                                   916
# 0.38 <Total asset turnover                                   137
# 0.7 < Debt ratio                                              47
# Debt ratio <= -0.68                                           18
# Operating gross profit margin <= -0.27                        20
# ROE <= -0.16                                                  63
# Total asset turnover <= -0.62                                161
# cash flow <= -0.2                                              0
#
#                                                -0.15 < Total asset turnover <= 0.38  \
# -0.002 < Debt ratio <= 0.7                                                       80
# -0.01 < Operating gross profit margin <= 0.29                                   602
# -0.04< ROA <= 0.36                                                                1
# -0.06 < cash flow                                                               619
# -0.15 < Total asset turnover <= 0.38                                              0
# -0.16 < ROE <= 0.04                                                             530
# -0.68 < Debt ratio <= -0.002                                                    508
# 0.26 < ROE                                                                       50
# 0.29 <Operating gross profit margin                                              10
# 0.36 < ROA                                                                      622
# 0.38 <Total asset turnover                                                        0
# 0.7 < Debt ratio                                                                 28
# Debt ratio <= -0.68                                                               7
# Operating gross profit margin <= -0.27                                           11
# ROE <= -0.16                                                                     43
# Total asset turnover <= -0.62                                                     0
# cash flow <= -0.2                                                                 4
#
#                                                -0.16 < ROE <= 0.04  \
# -0.002 < Debt ratio <= 0.7                                      97
# -0.01 < Operating gross profit margin <= 0.29                  768
# -0.04< ROA <= 0.36                                               1
# -0.06 < cash flow                                              771
# -0.15 < Total asset turnover <= 0.38                           530
# -0.16 < ROE <= 0.04                                              0
# -0.68 < Debt ratio <= -0.002                                   619
# 0.26 < ROE                                                       0
# 0.29 <Operating gross profit margin                              1
# 0.36 < ROA                                                     771
# 0.38 <Total asset turnover                                     121
# 0.7 < Debt ratio                                                40
# Debt ratio <= -0.68                                             16
# Operating gross profit margin <= -0.27                           3
# ROE <= -0.16                                                     0
# Total asset turnover <= -0.62                                  121
# cash flow <= -0.2                                                1
#
#                                                -0.68 < Debt ratio <= -0.002  \
# -0.002 < Debt ratio <= 0.7                                                0
# -0.01 < Operating gross profit margin <= 0.29                           710
# -0.04< ROA <= 0.36                                                        0
# -0.06 < cash flow                                                       738
# -0.15 < Total asset turnover <= 0.38                                    508
# -0.16 < ROE <= 0.04                                                     619
# -0.68 < Debt ratio <= -0.002                                              0
# 0.26 < ROE                                                               61
# 0.29 <Operating gross profit margin                                      13
# 0.36 < ROA                                                              753
# 0.38 <Total asset turnover                                              104
# 0.7 < Debt ratio                                                          0
# Debt ratio <= -0.68                                                       0
# Operating gross profit margin <= -0.27                                   30
# ROE <= -0.16                                                             73
# Total asset turnover <= -0.62                                           141
# cash flow <= -0.2                                                        15
#
#                                                0.26 < ROE  \
# -0.002 < Debt ratio <= 0.7                             15
# -0.01 < Operating gross profit margin <= 0.29          65
# -0.04< ROA <= 0.36                                      0
# -0.06 < cash flow                                      83
# -0.15 < Total asset turnover <= 0.38                   50
# -0.16 < ROE <= 0.04                                     0
# -0.68 < Debt ratio <= -0.002                           61
# 0.26 < ROE                                              0
# 0.29 <Operating gross profit margin                    19
# 0.36 < ROA                                             84
# 0.38 <Total asset turnover                              1
# 0.7 < Debt ratio                                        7
# Debt ratio <= -0.68                                     1
# Operating gross profit margin <= -0.27                  0
# ROE <= -0.16                                            0
# Total asset turnover <= -0.62                          33
# cash flow <= -0.2                                       1
#
#                                                0.29 <Operating gross profit margin  \
# -0.002 < Debt ratio <= 0.7                                                       5
# -0.01 < Operating gross profit margin <= 0.29                                    0
# -0.04< ROA <= 0.36                                                               0
# -0.06 < cash flow                                                               20
# -0.15 < Total asset turnover <= 0.38                                            10
# -0.16 < ROE <= 0.04                                                              1
# -0.68 < Debt ratio <= -0.002                                                    13
# 0.26 < ROE                                                                      19
# 0.29 <Operating gross profit margin                                              0
# 0.36 < ROA                                                                      20
# 0.38 <Total asset turnover                                                       2
# 0.7 < Debt ratio                                                                 1
# Debt ratio <= -0.68                                                              1
# Operating gross profit margin <= -0.27                                           0
# ROE <= -0.16                                                                     0
# Total asset turnover <= -0.62                                                    8
# cash flow <= -0.2                                                                0
#
#                                                0.36 < ROA  \
# -0.002 < Debt ratio <= 0.7                            114
# -0.01 < Operating gross profit margin <= 0.29         881
# -0.04< ROA <= 0.36                                      0
# -0.06 < cash flow                                     916
# -0.15 < Total asset turnover <= 0.38                  622
# -0.16 < ROE <= 0.04                                   771
# -0.68 < Debt ratio <= -0.002                          753
# 0.26 < ROE                                             84
# 0.29 <Operating gross profit margin                    20
# 0.36 < ROA                                              0
# 0.38 <Total asset turnover                            144
# 0.7 < Debt ratio                                       46
# Debt ratio <= -0.68                                    18
# Operating gross profit margin <= -0.27                 30
# ROE <= -0.16                                           76
# Total asset turnover <= -0.62                         165
# cash flow <= -0.2                                      15
#
#                                                0.38 <Total asset turnover  \
# -0.002 < Debt ratio <= 0.7                                             18
# -0.01 < Operating gross profit margin <= 0.29                         123
# -0.04< ROA <= 0.36                                                      0
# -0.06 < cash flow                                                     137
# -0.15 < Total asset turnover <= 0.38                                    0
# -0.16 < ROE <= 0.04                                                   121
# -0.68 < Debt ratio <= -0.002                                          104
# 0.26 < ROE                                                              1
# 0.29 <Operating gross profit margin                                     2
# 0.36 < ROA                                                            144
# 0.38 <Total asset turnover                                              0
# 0.7 < Debt ratio                                                       12
# Debt ratio <= -0.68                                                    10
# Operating gross profit margin <= -0.27                                 19
# ROE <= -0.16                                                           22
# Total asset turnover <= -0.62                                           0
# cash flow <= -0.2                                                       7
#
#                                                0.7 < Debt ratio  \
# -0.002 < Debt ratio <= 0.7                                    0
# -0.01 < Operating gross profit margin <= 0.29                46
# -0.04< ROA <= 0.36                                            1
# -0.06 < cash flow                                            47
# -0.15 < Total asset turnover <= 0.38                         28
# -0.16 < ROE <= 0.04                                          40
# -0.68 < Debt ratio <= -0.002                                  0
# 0.26 < ROE                                                    7
# 0.29 <Operating gross profit margin                           1
# 0.36 < ROA                                                   46
# 0.38 <Total asset turnover                                   12
# 0.7 < Debt ratio                                              0
# Debt ratio <= -0.68                                           0
# Operating gross profit margin <= -0.27                        0
# ROE <= -0.16                                                  0
# Total asset turnover <= -0.62                                 7
# cash flow <= -0.2                                             0
#
#                                                Debt ratio <= -0.68  \
# -0.002 < Debt ratio <= 0.7                                       0
# -0.01 < Operating gross profit margin <= 0.29                   17
# -0.04< ROA <= 0.36                                               0
# -0.06 < cash flow                                               18
# -0.15 < Total asset turnover <= 0.38                             7
# -0.16 < ROE <= 0.04                                             16
# -0.68 < Debt ratio <= -0.002                                     0
# 0.26 < ROE                                                       1
# 0.29 <Operating gross profit margin                              1
# 0.36 < ROA                                                      18
# 0.38 <Total asset turnover                                      10
# 0.7 < Debt ratio                                                 0
# Debt ratio <= -0.68                                              0
# Operating gross profit margin <= -0.27                           0
# ROE <= -0.16                                                     1
# Total asset turnover <= -0.62                                    1
# cash flow <= -0.2                                                0
#
#                                                Operating gross profit margin <= -0.27  \
# -0.002 < Debt ratio <= 0.7                                                          0
# -0.01 < Operating gross profit margin <= 0.29                                       0
# -0.04< ROA <= 0.36                                                                  0
# -0.06 < cash flow                                                                  20
# -0.15 < Total asset turnover <= 0.38                                               11
# -0.16 < ROE <= 0.04                                                                 3
# -0.68 < Debt ratio <= -0.002                                                       30
# 0.26 < ROE                                                                          0
# 0.29 <Operating gross profit margin                                                 0
# 0.36 < ROA                                                                         30
# 0.38 <Total asset turnover                                                         19
# 0.7 < Debt ratio                                                                    0
# Debt ratio <= -0.68                                                                 0
# Operating gross profit margin <= -0.27                                              0
# ROE <= -0.16                                                                       27
# Total asset turnover <= -0.62                                                       0
# cash flow <= -0.2                                                                  10
#
#                                                ROE <= -0.16  \
# -0.002 < Debt ratio <= 0.7                                2
# -0.01 < Operating gross profit margin <= 0.29            49
# -0.04< ROA <= 0.36                                        0
# -0.06 < cash flow                                        63
# -0.15 < Total asset turnover <= 0.38                     43
# -0.16 < ROE <= 0.04                                       0
# -0.68 < Debt ratio <= -0.002                             73
# 0.26 < ROE                                                0
# 0.29 <Operating gross profit margin                       0
# 0.36 < ROA                                               76
# 0.38 <Total asset turnover                               22
# 0.7 < Debt ratio                                          0
# Debt ratio <= -0.68                                       1
# Operating gross profit margin <= -0.27                   27
# ROE <= -0.16                                              0
# Total asset turnover <= -0.62                            11
# cash flow <= -0.2                                        13
#
#                                                Total asset turnover <= -0.62  \
# -0.002 < Debt ratio <= 0.7                                                16
# -0.01 < Operating gross profit margin <= 0.29                            157
# -0.04< ROA <= 0.36                                                         0
# -0.06 < cash flow                                                        161
# -0.15 < Total asset turnover <= 0.38                                       0
# -0.16 < ROE <= 0.04                                                      121
# -0.68 < Debt ratio <= -0.002                                             141
# 0.26 < ROE                                                                33
# 0.29 <Operating gross profit margin                                        8
# 0.36 < ROA                                                               165
# 0.38 <Total asset turnover                                                 0
# 0.7 < Debt ratio                                                           7
# Debt ratio <= -0.68                                                        1
# Operating gross profit margin <= -0.27                                     0
# ROE <= -0.16                                                              11
# Total asset turnover <= -0.62                                              0
# cash flow <= -0.2                                                          4
#
#                                                cash flow <= -0.2
# -0.002 < Debt ratio <= 0.7                                     0
# -0.01 < Operating gross profit margin <= 0.29                  5
# -0.04< ROA <= 0.36                                             0
# -0.06 < cash flow                                              0
# -0.15 < Total asset turnover <= 0.38                           4
# -0.16 < ROE <= 0.04                                            1
# -0.68 < Debt ratio <= -0.002                                  15
# 0.26 < ROE                                                     1
# 0.29 <Operating gross profit margin                            0
# 0.36 < ROA                                                    15
# 0.38 <Total asset turnover                                     7
# 0.7 < Debt ratio                                               0
# Debt ratio <= -0.68                                            0
# Operating gross profit margin <= -0.27                        10
# ROE <= -0.16                                                  13
# Total asset turnover <= -0.62                                  4
# cash flow <= -0.2                                              0

# %%
co_matrix_df
# Out:
#                                                -0.002 < Debt ratio <= 0.7  \
# -0.002 < Debt ratio <= 0.7                                              0
# -0.01 < Operating gross profit margin <= 0.29                         109
# -0.04< ROA <= 0.36                                                      0
# -0.06 < cash flow                                                     114
# -0.15 < Total asset turnover <= 0.38                                   80
# -0.16 < ROE <= 0.04                                                    97
# -0.68 < Debt ratio <= -0.002                                            0
# 0.26 < ROE                                                             15
# 0.29 <Operating gross profit margin                                     5
# 0.36 < ROA                                                            114
# 0.38 <Total asset turnover                                             18
# 0.7 < Debt ratio                                                        0
# Debt ratio <= -0.68                                                     0
# Operating gross profit margin <= -0.27                                  0
# ROE <= -0.16                                                            2
# Total asset turnover <= -0.62                                          16
# cash flow <= -0.2                                                       0
#
#                                                -0.01 < Operating gross profit margin <= 0.29  \
# -0.002 < Debt ratio <= 0.7                                                               109
# -0.01 < Operating gross profit margin <= 0.29                                              0
# -0.04< ROA <= 0.36                                                                         1
# -0.06 < cash flow                                                                        877
# -0.15 < Total asset turnover <= 0.38                                                     602
# -0.16 < ROE <= 0.04                                                                      768
# -0.68 < Debt ratio <= -0.002                                                             710
# 0.26 < ROE                                                                                65
# 0.29 <Operating gross profit margin                                                        0
# 0.36 < ROA                                                                               881
# 0.38 <Total asset turnover                                                               123
# 0.7 < Debt ratio                                                                          46
# Debt ratio <= -0.68                                                                       17
# Operating gross profit margin <= -0.27                                                     0
# ROE <= -0.16                                                                              49
# Total asset turnover <= -0.62                                                            157
# cash flow <= -0.2                                                                          5
#
#                                                -0.04< ROA <= 0.36  \
# -0.002 < Debt ratio <= 0.7                                      0
# -0.01 < Operating gross profit margin <= 0.29                   1
# -0.04< ROA <= 0.36                                              0
# -0.06 < cash flow                                               1
# -0.15 < Total asset turnover <= 0.38                            1
# -0.16 < ROE <= 0.04                                             1
# -0.68 < Debt ratio <= -0.002                                    0
# 0.26 < ROE                                                      0
# 0.29 <Operating gross profit margin                             0
# 0.36 < ROA                                                      0
# 0.38 <Total asset turnover                                      0
# 0.7 < Debt ratio                                                1
# Debt ratio <= -0.68                                             0
# Operating gross profit margin <= -0.27                          0
# ROE <= -0.16                                                    0
# Total asset turnover <= -0.62                                   0
# cash flow <= -0.2                                               0
#
#                                                -0.06 < cash flow  \
# -0.002 < Debt ratio <= 0.7                                   114
# -0.01 < Operating gross profit margin <= 0.29                877
# -0.04< ROA <= 0.36                                             1
# -0.06 < cash flow                                              0
# -0.15 < Total asset turnover <= 0.38                         619
# -0.16 < ROE <= 0.04                                          771
# -0.68 < Debt ratio <= -0.002                                 738
# 0.26 < ROE                                                    83
# 0.29 <Operating gross profit margin                           20
# 0.36 < ROA                                                   916
# 0.38 <Total asset turnover                                   137
# 0.7 < Debt ratio                                              47
# Debt ratio <= -0.68                                           18
# Operating gross profit margin <= -0.27                        20
# ROE <= -0.16                                                  63
# Total asset turnover <= -0.62                                161
# cash flow <= -0.2                                              0
#
#                                                -0.15 < Total asset turnover <= 0.38  \
# -0.002 < Debt ratio <= 0.7                                                       80
# -0.01 < Operating gross profit margin <= 0.29                                   602
# -0.04< ROA <= 0.36                                                                1
# -0.06 < cash flow                                                               619
# -0.15 < Total asset turnover <= 0.38                                              0
# -0.16 < ROE <= 0.04                                                             530
# -0.68 < Debt ratio <= -0.002                                                    508
# 0.26 < ROE                                                                       50
# 0.29 <Operating gross profit margin                                              10
# 0.36 < ROA                                                                      622
# 0.38 <Total asset turnover                                                        0
# 0.7 < Debt ratio                                                                 28
# Debt ratio <= -0.68                                                               7
# Operating gross profit margin <= -0.27                                           11
# ROE <= -0.16                                                                     43
# Total asset turnover <= -0.62                                                     0
# cash flow <= -0.2                                                                 4
#
#                                                -0.16 < ROE <= 0.04  \
# -0.002 < Debt ratio <= 0.7                                      97
# -0.01 < Operating gross profit margin <= 0.29                  768
# -0.04< ROA <= 0.36                                               1
# -0.06 < cash flow                                              771
# -0.15 < Total asset turnover <= 0.38                           530
# -0.16 < ROE <= 0.04                                              0
# -0.68 < Debt ratio <= -0.002                                   619
# 0.26 < ROE                                                       0
# 0.29 <Operating gross profit margin                              1
# 0.36 < ROA                                                     771
# 0.38 <Total asset turnover                                     121
# 0.7 < Debt ratio                                                40
# Debt ratio <= -0.68                                             16
# Operating gross profit margin <= -0.27                           3
# ROE <= -0.16                                                     0
# Total asset turnover <= -0.62                                  121
# cash flow <= -0.2                                                1
#
#                                                -0.68 < Debt ratio <= -0.002  \
# -0.002 < Debt ratio <= 0.7                                                0
# -0.01 < Operating gross profit margin <= 0.29                           710
# -0.04< ROA <= 0.36                                                        0
# -0.06 < cash flow                                                       738
# -0.15 < Total asset turnover <= 0.38                                    508
# -0.16 < ROE <= 0.04                                                     619
# -0.68 < Debt ratio <= -0.002                                              0
# 0.26 < ROE                                                               61
# 0.29 <Operating gross profit margin                                      13
# 0.36 < ROA                                                              753
# 0.38 <Total asset turnover                                              104
# 0.7 < Debt ratio                                                          0
# Debt ratio <= -0.68                                                       0
# Operating gross profit margin <= -0.27                                   30
# ROE <= -0.16                                                             73
# Total asset turnover <= -0.62                                           141
# cash flow <= -0.2                                                        15
#
#                                                0.26 < ROE  \
# -0.002 < Debt ratio <= 0.7                             15
# -0.01 < Operating gross profit margin <= 0.29          65
# -0.04< ROA <= 0.36                                      0
# -0.06 < cash flow                                      83
# -0.15 < Total asset turnover <= 0.38                   50
# -0.16 < ROE <= 0.04                                     0
# -0.68 < Debt ratio <= -0.002                           61
# 0.26 < ROE                                              0
# 0.29 <Operating gross profit margin                    19
# 0.36 < ROA                                             84
# 0.38 <Total asset turnover                              1
# 0.7 < Debt ratio                                        7
# Debt ratio <= -0.68                                     1
# Operating gross profit margin <= -0.27                  0
# ROE <= -0.16                                            0
# Total asset turnover <= -0.62                          33
# cash flow <= -0.2                                       1
#
#                                                0.29 <Operating gross profit margin  \
# -0.002 < Debt ratio <= 0.7                                                       5
# -0.01 < Operating gross profit margin <= 0.29                                    0
# -0.04< ROA <= 0.36                                                               0
# -0.06 < cash flow                                                               20
# -0.15 < Total asset turnover <= 0.38                                            10
# -0.16 < ROE <= 0.04                                                              1
# -0.68 < Debt ratio <= -0.002                                                    13
# 0.26 < ROE                                                                      19
# 0.29 <Operating gross profit margin                                              0
# 0.36 < ROA                                                                      20
# 0.38 <Total asset turnover                                                       2
# 0.7 < Debt ratio                                                                 1
# Debt ratio <= -0.68                                                              1
# Operating gross profit margin <= -0.27                                           0
# ROE <= -0.16                                                                     0
# Total asset turnover <= -0.62                                                    8
# cash flow <= -0.2                                                                0
#
#                                                0.36 < ROA  \
# -0.002 < Debt ratio <= 0.7                            114
# -0.01 < Operating gross profit margin <= 0.29         881
# -0.04< ROA <= 0.36                                      0
# -0.06 < cash flow                                     916
# -0.15 < Total asset turnover <= 0.38                  622
# -0.16 < ROE <= 0.04                                   771
# -0.68 < Debt ratio <= -0.002                          753
# 0.26 < ROE                                             84
# 0.29 <Operating gross profit margin                    20
# 0.36 < ROA                                              0
# 0.38 <Total asset turnover                            144
# 0.7 < Debt ratio                                       46
# Debt ratio <= -0.68                                    18
# Operating gross profit margin <= -0.27                 30
# ROE <= -0.16                                           76
# Total asset turnover <= -0.62                         165
# cash flow <= -0.2                                      15
#
#                                                0.38 <Total asset turnover  \
# -0.002 < Debt ratio <= 0.7                                             18
# -0.01 < Operating gross profit margin <= 0.29                         123
# -0.04< ROA <= 0.36                                                      0
# -0.06 < cash flow                                                     137
# -0.15 < Total asset turnover <= 0.38                                    0
# -0.16 < ROE <= 0.04                                                   121
# -0.68 < Debt ratio <= -0.002                                          104
# 0.26 < ROE                                                              1
# 0.29 <Operating gross profit margin                                     2
# 0.36 < ROA                                                            144
# 0.38 <Total asset turnover                                              0
# 0.7 < Debt ratio                                                       12
# Debt ratio <= -0.68                                                    10
# Operating gross profit margin <= -0.27                                 19
# ROE <= -0.16                                                           22
# Total asset turnover <= -0.62                                           0
# cash flow <= -0.2                                                       7
#
#                                                0.7 < Debt ratio  \
# -0.002 < Debt ratio <= 0.7                                    0
# -0.01 < Operating gross profit margin <= 0.29                46
# -0.04< ROA <= 0.36                                            1
# -0.06 < cash flow                                            47
# -0.15 < Total asset turnover <= 0.38                         28
# -0.16 < ROE <= 0.04                                          40
# -0.68 < Debt ratio <= -0.002                                  0
# 0.26 < ROE                                                    7
# 0.29 <Operating gross profit margin                           1
# 0.36 < ROA                                                   46
# 0.38 <Total asset turnover                                   12
# 0.7 < Debt ratio                                              0
# Debt ratio <= -0.68                                           0
# Operating gross profit margin <= -0.27                        0
# ROE <= -0.16                                                  0
# Total asset turnover <= -0.62                                 7
# cash flow <= -0.2                                             0
#
#                                                Debt ratio <= -0.68  \
# -0.002 < Debt ratio <= 0.7                                       0
# -0.01 < Operating gross profit margin <= 0.29                   17
# -0.04< ROA <= 0.36                                               0
# -0.06 < cash flow                                               18
# -0.15 < Total asset turnover <= 0.38                             7
# -0.16 < ROE <= 0.04                                             16
# -0.68 < Debt ratio <= -0.002                                     0
# 0.26 < ROE                                                       1
# 0.29 <Operating gross profit margin                              1
# 0.36 < ROA                                                      18
# 0.38 <Total asset turnover                                      10
# 0.7 < Debt ratio                                                 0
# Debt ratio <= -0.68                                              0
# Operating gross profit margin <= -0.27                           0
# ROE <= -0.16                                                     1
# Total asset turnover <= -0.62                                    1
# cash flow <= -0.2                                                0
#
#                                                Operating gross profit margin <= -0.27  \
# -0.002 < Debt ratio <= 0.7                                                          0
# -0.01 < Operating gross profit margin <= 0.29                                       0
# -0.04< ROA <= 0.36                                                                  0
# -0.06 < cash flow                                                                  20
# -0.15 < Total asset turnover <= 0.38                                               11
# -0.16 < ROE <= 0.04                                                                 3
# -0.68 < Debt ratio <= -0.002                                                       30
# 0.26 < ROE                                                                          0
# 0.29 <Operating gross profit margin                                                 0
# 0.36 < ROA                                                                         30
# 0.38 <Total asset turnover                                                         19
# 0.7 < Debt ratio                                                                    0
# Debt ratio <= -0.68                                                                 0
# Operating gross profit margin <= -0.27                                              0
# ROE <= -0.16                                                                       27
# Total asset turnover <= -0.62                                                       0
# cash flow <= -0.2                                                                  10
#
#                                                ROE <= -0.16  \
# -0.002 < Debt ratio <= 0.7                                2
# -0.01 < Operating gross profit margin <= 0.29            49
# -0.04< ROA <= 0.36                                        0
# -0.06 < cash flow                                        63
# -0.15 < Total asset turnover <= 0.38                     43
# -0.16 < ROE <= 0.04                                       0
# -0.68 < Debt ratio <= -0.002                             73
# 0.26 < ROE                                                0
# 0.29 <Operating gross profit margin                       0
# 0.36 < ROA                                               76
# 0.38 <Total asset turnover                               22
# 0.7 < Debt ratio                                          0
# Debt ratio <= -0.68                                       1
# Operating gross profit margin <= -0.27                   27
# ROE <= -0.16                                              0
# Total asset turnover <= -0.62                            11
# cash flow <= -0.2                                        13
#
#                                                Total asset turnover <= -0.62  \
# -0.002 < Debt ratio <= 0.7                                                16
# -0.01 < Operating gross profit margin <= 0.29                            157
# -0.04< ROA <= 0.36                                                         0
# -0.06 < cash flow                                                        161
# -0.15 < Total asset turnover <= 0.38                                       0
# -0.16 < ROE <= 0.04                                                      121
# -0.68 < Debt ratio <= -0.002                                             141
# 0.26 < ROE                                                                33
# 0.29 <Operating gross profit margin                                        8
# 0.36 < ROA                                                               165
# 0.38 <Total asset turnover                                                 0
# 0.7 < Debt ratio                                                           7
# Debt ratio <= -0.68                                                        1
# Operating gross profit margin <= -0.27                                     0
# ROE <= -0.16                                                              11
# Total asset turnover <= -0.62                                              0
# cash flow <= -0.2                                                          4
#
#                                                cash flow <= -0.2
# -0.002 < Debt ratio <= 0.7                                     0
# -0.01 < Operating gross profit margin <= 0.29                  5
# -0.04< ROA <= 0.36                                             0
# -0.06 < cash flow                                              0
# -0.15 < Total asset turnover <= 0.38                           4
# -0.16 < ROE <= 0.04                                            1
# -0.68 < Debt ratio <= -0.002                                  15
# 0.26 < ROE                                                     1
# 0.29 <Operating gross profit margin                            0
# 0.36 < ROA                                                    15
# 0.38 <Total asset turnover                                     7
# 0.7 < Debt ratio                                               0
# Debt ratio <= -0.68                                            0
# Operating gross profit margin <= -0.27                        10
# ROE <= -0.16                                                  13
# Total asset turnover <= -0.62                                  4
# cash flow <= -0.2                                              0

# %%
plt.figure(figsize=(6,6))
sns.heatmap(co_matrix_df,mask=co_matrix_df < 1,cmap='GnBu')
plt.title('stock', size = 14)
plt.suptitle('feature heat map',x = 0.435,y=0.95, fontsize=18)
# Out:
# Text(0.435, 0.95, 'feature heat map')

# %%
from matplotlib import pyplot as plt
import networkx as nx

# %%
plt.figure(figsize=(15,10))
plt.rcParams['font.sans-serif'] = ['SimHei']   
plt.rcParams['font.family']='sans-serif'
g = nx.Graph()
g.add_weighted_edges_from(co_matrix_weight)
pos=nx.spring_layout(g)
nx.draw_networkx_nodes(g, pos, alpha=0.5,node_size=[val*60 for (node, val) in g.degree()], node_color='#08c5b1')
nx.draw_networkx_edges(g, pos, node_color='b', alpha=0.2)
# for p in pos:  # raise text positions
#     pos[p][1] = pos[p][1] + 0.03
nx.draw_networkx_labels(g, pos, font_size = 10, font_family='sans-serif', alpha=0.8)
plt.title('stock info co-matrix', size = 10)
plt.suptitle('stock',x = 0.51,y=0.92, fontsize=20)
#plt.savefig("用詞共線圖_以每筆通聯紀錄為一句.png", dpi=100)
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
